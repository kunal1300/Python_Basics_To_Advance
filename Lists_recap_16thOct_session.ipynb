# %% [markdown]
# Lists are flexible, ordered collections that allow indexing, slicing, and many methods.
# When used with `for` loops, they help automate tasks and simplify data processing.

# %%
l1=list()

# %%
l1=[1,2,3,4,5]

# %%
type(l1)
# Out:
# list

# %%
l1.count(2)
# Out:
# 1

# %%
l1.extend([3,4,5,6])

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 3, 4, 5, 6]

# %%
l1.pop() #LIFO
# Out:
# 6

# %%
l1.remove(4)

# %%
l1
# Out:
# [1, 2, 3, 5, 3, 4, 5]

# %%
l1.reverse()

# %%
l1
# Out:
# [5, 4, 3, 5, 3, 2, 1]

# %%
l1.sort()

# %%
l1
# Out:
# [1, 2, 3, 3, 4, 5, 5]

# %%
l1.sort(reverse=True) #sort in reverse order

# %%
l1
# Out:
# [5, 5, 4, 3, 3, 2, 1]

# %%
l1[::-1]
# Out:
# [1, 2, 3, 3, 4, 5, 5]

# %%
sum(l1)
# Out:
# 23

# %%
min(l1)
# Out:
# 1

# %%
max(l1)
# Out:
# 5

# %%
str1=input()
# Out:
#  Hello

# %%
l1=eval(input()) #eval
# Out:
#  [1,2,3,4]

# %%
import ast #alternative safer way to get input of list from user allows only literals
l2=ast.literal_eval(input())
# Out:
#  [5,6,7,8]

# %%
l2
# Out:
# [5, 6, 7, 8]

# %%
max(l2)
# Out:
# 8

# %%
l2[1:3] #slicing ,last index is excluded
# Out:
# [6, 7]

# %%
l2[:-1] #till the last element (-1)
# Out:
# [5, 6, 7]

# %%
l3=l2.copy()

# %%
l3
# Out:
# [5, 6, 7, 8]

# %%
id(l3)==id(l2) #allocating new memory address
# Out:
# False

# %%
l2[1]=9

# %%
l2
# Out:
# [5, 9, 7, 8]

# %%
l3
# Out:
# [5, 6, 7, 8]

# %%
l2.append([5,4,7,8])

# %%
l2
# Out:
# [5, 9, 7, 8, [5, 4, 7, 8]]

# %%
l2[4][1]=10

# %%
l2
# Out:
# [5, 9, 7, 8, [5, 10, 7, 8]]

# %%
l3
# Out:
# [5, 6, 7, 8]

# %%
l3=l2.copy()

# %%
l3
# Out:
# [5, 9, 7, 8, [5, 10, 7, 8]]

# %%
l2[4][2]=99

# %%
l3
# Out:
# [5, 9, 7, 8, [5, 10, 99, 8]]

# %%
#to preserve the original even the nested lists, we need deepcopy
import copy
from copy import deepcopy

# %%
l4=deepcopy(l2)

# %%
l4
# Out:
# [5, 9, 7, 8, [5, 10, 99, 8]]

# %%
l2[4][0]=78

# %%
l2
# Out:
# [5, 9, 7, 8, [78, 10, 99, 8]]

# %%
l4
# Out:
# [5, 9, 7, 8, [5, 10, 99, 8]]
