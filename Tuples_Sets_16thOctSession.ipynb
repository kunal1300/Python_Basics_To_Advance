# %% [markdown]
# # Today's Agenda
# - Tuple
# > ### What is Tuple?
# > ### Different ways of creating Tuple?
# > ### What is Tuple indexing?
# > ### What are the built-in functions availble in Tuple!
# > ### what is main Difference between List and Tuple
# -------------------------------------------------------------
# - Sets
# > ### What is Sets?
# > ### Different ways of creating Sets?
# > ### How to call Set elements?
# > ### How to apply different set operations?
# > ### What are the built-in functions availble in sets!

# %% [markdown]
# # Tuple
# - Collection which can be indexed but immutable, (apple, 250)
# - So once we declare the tuple, we can not edit the data
# - tuple will be declared using `()`

# %% [markdown]
# ### tuple declaration

# %%
tup1=()
type(tup1)
# Out:
# tuple

# %%
tup2=tuple()

# %%
tup3=1,
type(tup3)
# Out:
# tuple

# %%
tup4=1,2,3,4 #comma separated
type(tup4)
# Out:
# tuple

# %%
tup4
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# ### How to add elements in tuple?

# %%
tup4=tup4+(1,2,3)

# %%
tup4
# Out:
# (1, 2, 3, 4, 1, 2, 3)

# %% [markdown]
# # duplicates permitted

# %% [markdown]
# ### packing and unpacking

# %%
#packing
a = 10
b = 20

t1 = (a, b)
print(t1)
# Out:
# (10, 20)

# %%
tup5=(5,6)

# %%
#unpacking
a,b=tup5

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %% [markdown]
# # tuple indexing
# - we can apply all the list indexing steps on the tuples

# %%
tup4
# Out:
# (1, 2, 3, 4, 1, 2, 3)

# %%
tup4[:4]
# Out:
# (1, 2, 3, 4)

# %%
tup4[1:]
# Out:
# (2, 3, 4, 1, 2, 3)

# %% [markdown]
# # tuple is a rigid data structure , so it has less scope of being manipulated

# %%
tup4.count(4) # how many times an element occurs
# Out:
# 1

# %%
tup4.index(3) #actual index + 1
# Out:
# 2

# %%
tup4=(1,[2,3],4,True)

# %%
tup4[1][1]=99

# %%
tup4
# Out:
# (1, [2, 99], 4, True)

# %% [markdown]
# - **Sets are like lists in that you use them for storing a collection of elements. Unlike lists, however, the elements in a set are nonduplicates and are not placed in any particular order.**
# - **with { } we declare a set**
# - **sets are unordered and unindexed**
# - **set will not allow duplicate elements**

# %%
# sets declaration
set1=set()

# %%
# Creating empty set
len(set1)
# Out:
# 0

# %%
set2={}
type(set2)
# Out:
# dict

# %%
# creating set using list
list1=[1,2,3,4,5,5,4,4,3]

# %%
set_list=set(list1)
set_list
#transforms into unqiue values
#data cleaning, preprocessing
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# # Built-in Functions

# %% [markdown]
# ### adding elements into a set

# %% [markdown]
# ### add()

# %%
set_list
# Out:
# {1, 2, 3, 4, 5, 9}

# %%
set_list.add(10)
set_list
# Out:
# {1, 2, 3, 4, 5, 9, 10}

# %%
# we can not add multiple elements using add
set_list.add(99,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # we can not add multiple elements using add
# ----> 2 set_list.add(99,100)
#
# TypeError: set.add() takes exactly one argument (2 given)

# %% [markdown]
# ### update()
# - we can add multiple elements using `update`

# %%
set_list.update([77,88,55])

# %%
set_list
# Out:
# {1, 2, 3, 4, 5, 9, 10, 55, 77, 88}

# %%
set_list.add(1.5)

# %%
set_list #unordered
# Out:
# {1, 1.5, 2, 3, 4, 5, 9, 10, 55, 77, 88}

# %% [markdown]
# ### sort()

# %%
set_sort={3,24,4,77,100,12,1}

# %%
list3=list(set_sort)
list3
list3.sort()
list3
# Out:
# [1, 3, 4, 12, 24, 77, 100]

# %%
set_sort=set(list3)
set_sort
# Out:
# {1, 3, 4, 12, 24, 77, 100}

# %%
sorted(set_sort)
# Out:
# [1, 3, 4, 12, 24, 77, 100]

# %% [markdown]
# ### discard()
# - Discard will discard the value from the set
# - if the value is not there in the set , discard will not throw any error

# %%
set_discard={4,5,6,7}

# %%
set_discard.discard(9)

# %%
set_discard
# Out:
# {4, 6, 7}

# %% [markdown]
# ### remove()
# - Remove will remove the value from the set if the value exists, if not
# - it generates error

# %%
set_discard.remove(9) #if element not present, it throws keyerror
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 set_discard.remove(9)
#
# KeyError: 9

# %% [markdown]
# ### pop()
# - pop is used to delete element from the given set
# - we can not the predict the which element will be delete because set is unindexed

# %%
set_discard.pop() #in case of set pop removes any item randomly
set_discard
# Out:
# {6, 7}

# %% [markdown]
# ### clear()

# %%
set_discard.clear()
set_discard
# Out:
# set()

# %% [markdown]
# # Other set operations
# - 1. union()
# - 2. intersection()
# - 3. differeence()

# %% [markdown]
# ### union()

# %%
#Sets union, intersection and difference
setA={1,2,3,4,5,6}
setB = {2,3,4,5,6,7,8}
setU=setA.union(setB)

# %%
setU
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
setA.intersection(setB) #common elements
# Out:
# {2, 3, 4, 5, 6}

# %%
setA&setB # & operator also does the same thing as intersection
# Out:
# {2, 3, 4, 5, 6}

# %%
setA|setB #| operator is also an alternative for union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ### intersection()

# %%
#Sets union, intersection and difference
setA.intersection(setB) #common elements

# %% [markdown]
# ### difference()

# %%
setA.difference(setB) # - operator
setA-setB
# Out:
# {1}

# %% [markdown]
# ### symmetric difference

# %%
#Previous class notes

#Symmetric difference prints values of A and B and eliminates the common
#elements from both the sets

#This can also be written as below notation

#Both these gives same output
setA.symmetric_difference(setB)
(setA|setB)-(setA&setB)
# Out:
# {1, 7, 8}

# %% [markdown]
# # 2. Manipulating and Accessing Sets
# - You can add an element to a set or remove an element by using the add(e) or remove(e) method. You can use the len, min, max, and sum functions on a set, and a for loop to traverse all elements in a set. You can use the in or not in operator to determine whether an element is in the set.

# %%
 # Use function len
 # Use max
 # Use min
 # Use sum

# %%
set_maths={1,2,3,5,7,9,10}

# %%
len(set_maths)
# Out:
# 7

# %%
max(set_maths)
# Out:
# 10

# %%
min(set_maths)
# Out:
# 1

# %%
sum(set_maths)
# Out:
# 37

# %%
#do we have 3 in this set very fast as set is hashable
3 in set_maths
# Out:
# True

# %%
99 not in set_maths
# Out:
# True

# %%
for i in set_maths: #iterable
    print(i)
# Out:
# 1
# 2
# 3
# 5
# 7
# 9
# 10
