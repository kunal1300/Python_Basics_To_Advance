# %% [markdown]
# ### 1. Create a List: Create a list of your 5 favorite fruits.

# %%
Fruits = ["Apple","Banana","Stawberry","Grapes","Pears"]
print(Fruits)
# Out:
# ['Apple', 'Banana', 'Stawberry', 'Grapes', 'Pears']

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Access Elements: How do you access the second item in the list my_list = [10, 20, 30, 40, 50]?

# %%
my_list = [10, 20, 30, 40, 50]
my_list[1]
# Out:
# 20

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Add Items: Add the number 60 to the list [1, 2, 3, 4, 5].

# %%
list1=[1,2,3,4,5]
list1.append(60)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 60]

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Remove Items: Remove the number 3 from the list [1, 2, 3, 4, 5].

# %%
list1=[1, 2, 3, 4, 5]
list1.remove(3)
list1
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# ---

# %% [markdown]
# ### 5. List Length: Find the length of the list numbers = [5, 10, 15, 20, 25]

# %%
numbers = [5, 10, 15, 20, 25]
print(len(numbers))
# Out:
# 5

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Check Membership: Write a program to check if the number 10 is in the list [1, 2, 3, 4, 5, 10].

# %%
list1=[1, 2, 3, 4, 5, 10]
print(10 in list1)
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ### 7. Loop Through List: Write a loop to print each item in the list ['apple', 'banana', 'cherry'].

# %%
list1= ['apple', 'banana', 'cherry']
for i in list1:
    print(i)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ---

# %% [markdown]
# ### 8. List Slicing: What does my_list[1:4] return if my_list = [0, 1, 2, 3, 4, 5]?

# %%
my_list = [0, 1, 2, 3, 4, 5]
print("before Slicing",my_list)
print("After Slicing:",my_list[1:4])
# Out:
# before Slicing [0, 1, 2, 3, 4, 5]
# After Slicing: [1, 2, 3]

# %% [markdown]
# ---

# %% [markdown]
# ### 9. Reverse a List: How do you reverse the list [1, 2, 3, 4, 5]?

# %%
my_list = [1, 2, 3, 4, 5]
print("Original= ",my_list)
print("Reverse= ",my_list[::-1])
# Out:
# Original=  [1, 2, 3, 4, 5]
# Reverse=  [5, 4, 3, 2, 1]

# %% [markdown]
# ---

# %% [markdown]
# ### 10. Find Maximum: Write a program to find the maximum number in the list [3, 7, 1, 9, 5].

# %%
my_list=[3, 7, 1, 9, 5]
print(max(my_list))
# Out:
# 9
