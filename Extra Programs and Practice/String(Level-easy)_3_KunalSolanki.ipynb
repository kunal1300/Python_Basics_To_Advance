# %% [markdown]
# # Create markdown file for String Functions (Level-Easy)

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Write a Python program to convert "good morning" into uppercase.

# %%
data="good morning"
data=data.upper()
print(data)
# Out:
# GOOD MORNING

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Write a Python program to convert "HELLO WORLD" into lowercase.

# %%
data="GOOD MORNING"
data= data.lower()
print(data)
# Out:
# good morning

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Write a Python program to convert "python programming language" into title case.

# %%
data="python programming language"
print("Orginal:",data)
data = data.title()
print("After:",data)
# Out:
# Orginal: python programming language
# After: Python Programming Language

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Write a Python program to count how many times "o" appears in "hello world".

# %%
data="hello world"
print(data.count("o"))
# Out:
# 2

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Write a Python program to check if "Learning Python" starts with "Learning".

# %%
data="Learning Python"
print(data.startswith("Learning"))
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Write a Python program to check if "Practice makes perfect" ends with "perfect".

# %%
data="Practice makes perfect"
print(data.endswith("perfect"))
# Out:
# True

# %% [markdown]
# ---

# %% [markdown]
# ### 7. Write a Python program to replace "blue" with "red" in "The sky is blue".

# %%
data="The sky is blue"
print("Original:",data)
data=data.replace("blue","red")
print("After: ",data)
# Out:
# Original: The sky is blue
# After:  The sky is red

# %% [markdown]
# ---

# %% [markdown]
# ### 8. Write a Python program to find the index of "code" in "I love to code in Python".

# %%
data="I love to code in Python"
print("The start index for 'code' is",data.find("code"))
# Out:
# The start index for 'code' is 10

# %% [markdown]
# ---

# %% [markdown]
# ### 9. Write a Python program to remove spaces from the string " data science ".

# %%
data=" data science "
data=data.strip()
print(data)
# Out:
# data science

# %% [markdown]
# ---

# %% [markdown]
# ### 10. Write a Python program to split "cat,dog,rat" by commas and join them with "-".

# %%
data = "cat,dog,rat"
data = "-".join(data.split(","))
print(data)
# Out:
# cat-dog-rat

# %% [markdown]
# ---
