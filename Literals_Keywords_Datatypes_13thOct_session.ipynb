# %%
a=10

# %%
a
# Out:
# 10

# %%
a=9

# %%
a
# Out:
# 9

# %%
type(a)
# Out:
# int

# %%
a=True

# %%
type(a)
# Out:
# bool

# %%
val1=8.56

# %%
type(val1)
# Out:
# float

# %%
int(val1)
# Out:
# 8

# %%
l1=[1,2,3,4]

# %%
type(l1)
# Out:
# list

# %%
dict1={"name":"Shivani"}

# %%
type(dict1)
# Out:
# dict

# %%
t1=(1,2,3)

# %%
type(t1)
# Out:
# tuple

# %%
set1={1,2,3,5}

# %%
type(set1)
# Out:
# set

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
type(None)
# Out:
# NoneType

# %%
from math import pi

# %%
complex1=1+5j

# %%
type(complex1)
# Out:
# complex

# %%
type(range(4))
# Out:
# range

# %%
range(4)
# Out:
# range(0, 4)

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
set([1,2,3,3,4,4])
# Out:
# {1, 2, 3, 4}

# %%
byte1=b'hello'

# %%
type(byte1)
# Out:
# bytes

# %%
byte1
# Out:
# b'hello'

# %%
def func():
    pass

# %%
type(func)
# Out:
# function

# %%
import math
type(math)
# Out:
# module

# %%
class car:
    pass

# %%
type(car)
# Out:
# type

# %%
obj=car()

# %%
type(obj)
# Out:
# __main__.car

# %%
import collections
from collections import Counter

# %%
count1=Counter()

# %%
type(count1)
# Out:
# collections.Counter

# %%
input()
# Out:
#  hello
# 'hello'

# %%
user_input=input()#snake case notation
# Out:
#  python

# %%
print("Our favorite programming language ",user_input)
# Out:
# Our favorite programming language  python

# %%
#formatted strings
#f strings
a,b =10,15
print(f"{a} is an integer")
print(f"{a+b} is example of sum") #expression within f strings
str1="Harry"
print(f"Hello {str1},how are you?")
# Out:
# 10 is an integer
# 25 is example of sum
# Hello Harry,how are you?
